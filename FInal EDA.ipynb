# %%
import json
import numpy as np

# Load JSON data from file
with open(r'Final data All Week.json', 'r') as file:
    data = json.load(file)

# Extract lengths of 'instruction' and 'response' texts
instruction_lengths = [len(item['instruction']) for item in data]
response_lengths = [len(item['response']) for item in data]

# Calculate statistics for 'instruction' lengths
instruction_mean_length = np.mean(instruction_lengths)
instruction_std_deviation = np.std(instruction_lengths)
instruction_max_length = max(instruction_lengths)

# Calculate statistics for 'response' lengths
response_mean_length = np.mean(response_lengths)
response_std_deviation = np.std(response_lengths)
response_max_length = max(response_lengths)

# Print results for 'instruction'
print("Statistics for 'instruction' lengths:")
print(f"Mean length: {instruction_mean_length:.2f} characters")
print(f"Standard deviation: {instruction_std_deviation:.2f} characters")
print(f"Maximum length: {instruction_max_length} characters")

# Print results for 'response'
print("\nStatistics for 'response' lengths:")
print(f"Mean length: {response_mean_length:.2f} characters")
print(f"Standard deviation: {response_std_deviation:.2f} characters")
print(f"Maximum length: {response_max_length} characters")
# Out:
# Statistics for 'instruction' lengths:
# Mean length: 75.44 characters
# Standard deviation: 24.15 characters
# Maximum length: 460 characters
#
# Statistics for 'response' lengths:
# Mean length: 249.08 characters
# Standard deviation: 156.57 characters
# Maximum length: 2615 characters

# %%
import json
import matplotlib.pyplot as plt

# Load JSON data from file
with open(r'Final data All Week.json', 'r') as file:
    data = json.load(file)

# Count occurrences of each category
category_counts = {}
for item in data:
    try:
        category = item['category']
        category_counts[category] = category_counts.get(category, 0) + 1
    except KeyError:
        # If 'category' key doesn't exist in the item, skip it
        pass

print("Category Counts:")
for category, count in category_counts.items():
    print(f"{category}: {count}")

# Sort categories by count in descending order
sorted_categories = sorted(category_counts.items(), key=lambda x: x[1], reverse=True)
sorted_categories_labels = [x[0] for x in sorted_categories]
sorted_categories_counts = [x[1] for x in sorted_categories]

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(sorted_categories_labels, sorted_categories_counts)
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Count of Each Category')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Category Counts:
# information_extraction: 1244
# closed_qa: 1591
# general_qa: 1606
# open_qa: 1750
# summarisation: 124
# brainstorming: 1013
# summarization: 500
# classification: 301
# creative_writing: 385
# question_answer: 7
# explanation: 312
# application: 1
# clarification: 27
# definition: 10
# enumeration: 1
# example: 2
# comparison: 2
# identification: 3
# summary: 2
# discussion: 2
# prediction: 1
# solution: 1
# inference: 4
# HOG, SIFT, and SURF are traditional feature extraction methods mentioned in the text.: 1
# : 10
# the slide contains exaple of training procedure: 1
#  : 1
# Some disadvantages of using HOG features include: 1) Processing speed is not very fast, 2) HOG features are not inherently rotation invariant, and 3) Just like pixel-based approaches, HOG is also not rotation invariant.: 1
# reative_writing: 1
# PCA can reduce the complexity of the data by removing irrelevant features and capturing essential information, thus enhancing the performance of classification algorithms.: 1
# Covariance can be utilized to identify patterns or dependencies between different dimensions, helping analysts understand the underlying structure of the dataset and inform further analyses or modeling techniques.: 1
# In image processing, eigenvalues and eigenvectors can be used for image compression and feature extraction, while in network analysis, they can help identify important nodes or clusters in a network.: 1
# PCA with SVD can be utilized to preprocess high-dimensional data before feeding it into machine learning algorithms, reducing computational complexity and improving model performance.: 2
# Information Extraction: 16
# Open QA: 16
# Summarization: 208
# Classification: 5
# Creative Writing: 4
# Brainstorming: 7
# General QA: 10
# Closed QA: 12
# Classificatio: 1
# Some of the movies mentioned include Ninja, Cat, Angel, Nursey, Tongey, Chained, Frozen, Bambi, Titanic, Goodfellas, Dumbo, Thor, Twilight, and Tangled.: 1
# The choice of K determines the number of principal components used in the approximation, with higher values potentially capturing more variance but also increasing computational complexity.: 1
# The probability threshold ensures a high level of confidence in the accuracy of the chosen columns for the CU decomposition.: 1
# information_extraction : 1
# general_qa:: 3
# General_qa: 1
# Open Q&A: 1
# Summerization: 74
# speculative: 2
# /tmp/ipykernel_5999/1672137928.py:34: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
